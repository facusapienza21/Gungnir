# %% [markdown]
# # Example of how to Preprocess OGGM Data

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# File ~/.local/lib/python3.11/site-packages/pandas/__init__.py:19
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#      18 if _missing_dependencies:  # pragma: no cover
# ---> 19     raise ImportError(
#      20         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      21     )
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
import gungnir as gn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gungnir as gn
#
# File ~/Dropbox/Projects/2025_ODINN_inversion/repos/Gungnir-facusapienza21/gungnir/gungnir/__init__.py:9
#       6 __all__ = ["utils", "preprocessing"]
#       8 from .utils import *
# ----> 9 from .preprocessing import *
#
# File ~/Dropbox/Projects/2025_ODINN_inversion/repos/Gungnir-facusapienza21/gungnir/gungnir/preprocessing.py:2
#       1 import sys
# ----> 2 from oggm import cfg, utils, workflow, tasks, global_tasks
#       3 from oggm.shop import bedtopo, millan22, glathida
#       4 from MBsandbox.mbmod_daily_oneflowline import process_w5e5_data
#
# File ~/.local/lib/python3.11/site-packages/oggm/__init__.py:39
#      35 warnings.filterwarnings(action='ignore', category=FutureWarning, module=r'.*geopandas')
#      37 # API
#      38 # Some decorators used by many
# ---> 39 from oggm.utils import entity_task, global_task, DEFAULT_BASE_URL
#      41 # Classes
#      42 from oggm.utils import GlacierDirectory
#
# File ~/.local/lib/python3.11/site-packages/oggm/utils/__init__.py:2
#       1 # flake8: noqa
# ----> 2 from oggm.utils._downloads import *
#       3 from oggm.utils._funcs import *
#       4 from oggm.utils._workflow import *
#
# File ~/.local/lib/python3.11/site-packages/oggm/utils/_downloads.py:29
#      26 import json
#      28 # External libs
# ---> 29 import pandas as pd
#      30 import numpy as np
#      31 import shapely.geometry as shpg
#
# File ~/.local/lib/python3.11/site-packages/pandas/__init__.py:19
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#      18 if _missing_dependencies:  # pragma: no cover
# ---> 19     raise ImportError(
#      20         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      21     )
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %% [markdown]
# We can process individual glaciers. Exploration of Glacier data is done with OGGM (see [working with rgi tutorial](https://tutorials.oggm.org/stable/notebooks/tutorials/working_with_rgi.html)).
# As there explained, we can find an individual glacier using the [GLIMS glacier viewer](https://www.glims.org/maps/glims).

# %%
working_dir = "/Users/sapienza/.ODINN/ODINN_prepro"

# Bossons
# gn.preprocessing_glaciers(["RGI60-11.03646"], working_dir=working_dir) 

# Mer de Glace
# gn.preprocessing_glaciers(["RGI60-11.03643"], working_dir=working_dir) 

# Perito Moreno 
# gn.preprocessing_glaciers(["RGI60-17.00312"], working_dir=working_dir) 

# Some glacier in the Peruvian Andes
gn.preprocessing_glaciers(["RGI60-11.02596"], working_dir=working_dir) 


# gn.preprocessing_glaciers(["RGI60-11.00872"], working_dir=working_dir)
# Out:
# 2025-02-19 13:48:13: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2025-02-19 13:48:13: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2025-02-19 13:48:13: oggm.cfg: Multiprocessing: using all available processors (N=11)
# 2025-02-19 13:48:13: oggm.cfg: Multiprocessing switched ON after user settings.
# 2025-02-19 13:48:13: oggm.cfg: PARAMS['border'] changed from `80` to `10`.
# 2025-02-19 13:48:13: oggm.cfg: PARAMS['hydro_month_nh'] changed from `10` to `1`.
# 2025-02-19 13:48:13: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# Working directory: /Users/sapienza/.ODINN/ODINN_prepro
# 2025-02-19 13:48:13: oggm.workflow: init_glacier_directories from prepro level 2 on 1 glaciers.
# 2025-02-19 13:48:13: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers
# 2025-02-19 13:48:14: oggm.workflow: Execute entity tasks [gridded_attributes] on 1 glaciers
# 2025-02-19 13:48:14: oggm.core.gis: (RGI60-11.02596) gridded_attributes
# 2025-02-19 13:48:14: oggm.workflow: Execute entity tasks [glacier_masks] on 1 glaciers
# 2025-02-19 13:48:14: oggm.core.gis: (RGI60-11.02596) glacier_masks
# 2025-02-19 13:48:14: oggm.workflow: Execute entity tasks [add_consensus_thickness] on 1 glaciers
# 2025-02-19 13:48:14: oggm.shop.bedtopo: (RGI60-11.02596) add_consensus_thickness
# 2025-02-19 13:48:14: oggm.utils: Downloading https://cluster.klima.uni-bremen.de/~fmaussion/icevol/composite/RGI60-11/RGI60-11.02596_thickness.tif to /Users/sapienza/OGGM/download_cache/cluster.klima.uni-bremen.de/~fmaussion/icevol/composite/RGI60-11/RGI60-11.02596_thickness.tif...
# 100% of  90.9 KiB |######################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2025-02-19 13:48:15: oggm.workflow: Execute entity tasks [thickness_to_gdir] on 1 glaciers
# 2025-02-19 13:48:15: oggm.shop.millan22: (RGI60-11.02596) thickness_to_gdir
# 2025-02-19 13:48:15: oggm.workflow: Execute entity tasks [velocity_to_gdir] on 1 glaciers
# 2025-02-19 13:48:15: oggm.shop.millan22: (RGI60-11.02596) velocity_to_gdir
# 2025-02-19 13:48:15: oggm.workflow: Execute entity tasks [glathida_to_gdir] on 1 glaciers
# 2025-02-19 13:48:15: oggm.shop.glathida: (RGI60-11.02596) glathida_to_gdir
# 2025-02-19 13:48:15: MBsandbox.mbmod_daily_oneflowline: (RGI60-11.02596) process_w5e5_data
# 2025-02-19 13:48:15: oggm.utils: Applying global task compile_task_log on 1 glaciers
# dem path:  /Users/sapienza/.ODINN/ODINN_prepro/per_glacier/RGI60-11/RGI60-11.02/RGI60-11.02596/dem.tif
